# %%
#Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import Billionaires dataset
data_file = pd.read_csv(r"C:\Users\parul\Downloads\Billionaires_Statistics_Dataset.csv")
print(data_file.head())
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
#To check variable ranges and percentile
print(data_file.describe())
# Out:
#               rank     finalWorth          age    birthYear   birthMonth  \
# count  2640.000000    2640.000000  2575.000000  2564.000000  2564.000000
# mean   1289.159091    4623.787879    65.140194  1957.183307     5.740250
# std     739.693726    9834.240939    13.258098    13.282516     3.710085
# min       1.000000    1000.000000    18.000000  1921.000000     1.000000
# 25%     659.000000    1500.000000    56.000000  1948.000000     2.000000
# 50%    1312.000000    2300.000000    65.000000  1957.000000     6.000000
# 75%    1905.000000    4200.000000    75.000000  1966.000000     9.000000
# max    2540.000000  211000.000000   101.000000  2004.000000    12.000000
#
#           birthDay  cpi_country  cpi_change_country  \
# count  2564.000000  2456.000000         2456.000000
# mean     12.099844   127.755204            4.364169
# std       9.918876    26.452951            3.623763
# min       1.000000    99.550000           -1.900000
# ...

# %%
#To print missing values
print(data_file.isnull().sum())
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                             65
# country                                         38
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# birthDate                                       76
# lastName                                         0
# firstName                                        3
# title                                         2301
# ...

# %%
#Storing top 10 Billionaire in new variable
df2 = data.sort_values(by = ["finalWorth"], ascending=False).head(10)
#plotting graph
plt.figure(figsize=(8, 8))
ax = sns.barplot(x=df2['personName'],y=df2['finalWorth'],data=df2)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
plt.show()

# %%
#Gender based total number of Billionaires
a = data_file["gender"].value_counts().head()
index = a.index
genders = a.values
custom_colors = ["blue", "pink"]
plt.figure(figsize=(4, 4))
plt.pie(genders, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.4, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=10)
plt.title("Gender based total Number of Billionaires", fontsize=18)
plt.show()

# %%
#Filter the Female Billionaire's data
data= data_file[data_file['gender'] == "F"]

# %%
#Top 7 countries with most number of female Billionaires
a= data["countryOfCitizenship"].value_counts().head(7)
index = a.index
Countries = a.values
custom_colors = ["orange", "red", "blue", "skyblue", "grey", "pink", "green"]
plt.figure(figsize=(5, 5))
plt.pie(Countries, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 7 Countries with Most Number of Female Billionaires", fontsize=20)
plt.show()

# %%
#To visualize top 7 domains of Female Billionaires
df = data.sort_values(by = ["finalWorth"], ascending=False).head(10)
a = data["source"].value_counts().head()
index = a.index
sources = a.values
custom_colors = ["skyblue", "blue", "red", "green", "orange"]
plt.figure(figsize=(4, 4))
plt.pie(sources, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.4, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=10)
plt.title("Top 7 Domains of Female Billionaires", fontsize=18)
plt.show()

# %%
#Top 7 Industries where most number of female billionaires do business
a = data["industries"].value_counts().head(7)
index = a.index
industries = a.values
custom_colors = ["blue", "red", "orange", "yellow", 'green', "pink", "grey"]
plt.figure(figsize=(4, 4))
plt.pie(industries, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.4, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=10)
plt.title("Top 7 Industries where Most Number of Female Billionaires do business", fontsize=18)
plt.show()
